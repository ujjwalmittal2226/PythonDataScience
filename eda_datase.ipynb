# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\Dog1 Breads Around.csv")

# %%
df
# Out:
#                             Name       Origin          Type  \
# 0                  Affenpinscher      Germany           Toy
# 1                   Afghan Hound  Afghanistan         Hound
# 2               Airedale Terrier      England       Terrier
# 3                          Akita        Japan       Working
# 4               Alaskan Malamute   Alaska USA       Working
# ..                           ...          ...           ...
# 154             Wire Fox Terrier      England       Terrier
# 155         Wirehaired Dachshund      Germany         Hound
# 156  Wirehaired Pointing Griffon  Netherlands      Sporting
# 157               Xoloitzcuintli       Mexico  Non-Sporting
# 158            Yorkshire Terrier      England           Toy
#
#              Unique Feature  Friendly Rating (1-10)  Life Span         Size  \
# 0          Monkey-like face                       7         14        Small
# 1           Long silky coat                       5         13        Large
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Origin', 'Type', 'Unique Feature', 'Friendly Rating (1-10)',
#        'Life Span', 'Size', 'Grooming Needs',
#        'Exercise Requirements (hrs/day)', 'Good with Children',
#        'Intelligence Rating (1-10)', 'Shedding Level', 'Health Issues Risk',
#        'Weight', 'Training Difficulty (1-10)'],
#       dtype='object')

# %%
df.head()
# Out:
#                Name       Origin     Type          Unique Feature  \
# 0     Affenpinscher      Germany      Toy        Monkey-like face
# 1      Afghan Hound  Afghanistan    Hound         Long silky coat
# 2  Airedale Terrier      England  Terrier     Largest of terriers
# 3             Akita        Japan  Working          Strong loyalty
# 4  Alaskan Malamute   Alaska USA  Working  Strong pulling ability
#
#    Friendly Rating (1-10)  Life Span    Size Grooming Needs  \
# 0                       7         14   Small           High
# 1                       5         13   Large      Very High
# 2                       8         12  Medium           High
# 3                       6         11   Large       Moderate
# 4                       7         11   Large           High
#
#    Exercise Requirements (hrs/day) Good with Children  \
# 0                              1.5                Yes
# 1                              2.0                 No
# ...

# %%
df.sort_values('Life Span')
# Out:
#                      Name       Origin          Type  \
# 79        Irish Wolfhound      Ireland         Hound
# 128    Scottish Deerhound     Scotland         Hound
# 124         Saint Bernard  Switzerland       Working
# 15   Bernese Mountain Dog  Switzerland       Working
# 67             Great Dane      Germany       Working
# ..                    ...          ...           ...
# 114          Poodle (Toy)       France           Toy
# 112    Poodle (Miniature)       France  Non-Sporting
# 93     Manchester Terrier      England       Terrier
# 143    Standard Schnauzer      Germany      Standard
# 36              Chihuahua       Mexico           Toy
#
#                 Unique Feature  Friendly Rating (1-10)  Life Span  \
# 79           Tallest dog breed                       7          7
# 128             Greyhound-like                       6          8
# 124                 Large size                       9          8
# ...

# %%
df[df['Average Weight'(kg)]>20]
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\4085921783.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df[df['Average Weight'(kg)]>20]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\4085921783.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df[df['Average Weight'(kg)]>20]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\4085921783.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df[df['Average Weight'(kg)]>20]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\4085921783.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df[df['Average Weight'(kg)]>20]
# ...

# %%
df.rename(columns = {'Average Weight (kg)' : 'Weight'}, inplace = True)

# %%
df.['columns']
# Out:
#   Cell In[49], line 1
#     df.['columns']
#        ^
# SyntaxError: invalid syntax

# %%
df.['Weight']
# Out:
#   Cell In[51], line 1
#     df.['Weight']
#        ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#                Name       Origin     Type          Unique Feature  \
# 0     Affenpinscher      Germany      Toy        Monkey-like face
# 1      Afghan Hound  Afghanistan    Hound         Long silky coat
# 2  Airedale Terrier      England  Terrier     Largest of terriers
# 3             Akita        Japan  Working          Strong loyalty
# 4  Alaskan Malamute   Alaska USA  Working  Strong pulling ability
#
#    Friendly Rating (1-10)  Life Span    Size Grooming Needs  \
# 0                       7         14   Small           High
# 1                       5         13   Large      Very High
# 2                       8         12  Medium           High
# 3                       6         11   Large       Moderate
# 4                       7         11   Large           High
#
#    Exercise Requirements (hrs/day) Good with Children  \
# 0                              1.5                Yes
# 1                              2.0                 No
# ...

# %%
#df.convert_dtypes('Weight') 
df.dtypes
# Out:
# Name                                object
# Origin                              object
# Type                                object
# Unique Feature                      object
# Friendly Rating (1-10)               int64
# Life Span                            int64
# Size                                object
# Grooming Needs                      object
# Exercise Requirements (hrs/day)    float64
# Good with Children                  object
# Intelligence Rating (1-10)           int64
# Shedding Level                      object
# Health Issues Risk                  object
# Weight                             float64
# Training Difficulty (1-10)           int64
# dtype: object

# %%
#df['Weight'] = pd.to_in(df['Weight'])
#df['Weight'] = df['Weight'].astype(int)
df['Weight'] = pd.to_numeric(df['Weight'], errors='coerce')
df
# Out:
#                             Name       Origin          Type  \
# 0                  Affenpinscher      Germany           Toy
# 1                   Afghan Hound  Afghanistan         Hound
# 2               Airedale Terrier      England       Terrier
# 3                          Akita        Japan       Working
# 4               Alaskan Malamute   Alaska USA       Working
# ..                           ...          ...           ...
# 154             Wire Fox Terrier      England       Terrier
# 155         Wirehaired Dachshund      Germany         Hound
# 156  Wirehaired Pointing Griffon  Netherlands      Sporting
# 157               Xoloitzcuintli       Mexico  Non-Sporting
# 158            Yorkshire Terrier      England           Toy
#
#              Unique Feature  Friendly Rating (1-10)  Life Span         Size  \
# 0          Monkey-like face                       7         14        Small
# 1           Long silky coat                       5         13        Large
# ...

# %%
df['Weight'].replace('25-Jul', '25', inplace = True)

# %%
df.sort_values('Weight')
# Out:
#                    Name       Origin     Type         Unique Feature  \
# 148     Toy Fox Terrier          USA      Toy  Miniature Fox Terrier
# 36            Chihuahua       Mexico      Toy     Smallest dog breed
# 158   Yorkshire Terrier      England      Toy        Long silky coat
# 92              Maltese        Malta      Toy        Pure white coat
# 111          Pomeranian      Germany      Toy     Fluffy double coat
# ..                  ...          ...      ...                    ...
# 98         Newfoundland       Canada  Working   Water rescue ability
# 67           Great Dane      Germany  Working             Giant size
# 124       Saint Bernard  Switzerland  Working             Large size
# 97   Neapolitan Mastiff        Italy  Working     Wrinkly loose skin
# 94              Mastiff      England  Working           Massive size
#
#      Friendly Rating (1-10)  Life Span   Size Grooming Needs  \
# 148                       8         15    Toy       Moderate
# ...

# %%
df['Weight'].replace('2.0', 'n', inplace = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\2966115071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weight'].replace('2.0', 'n', inplace = True)

# %%
df.sort_values('Weight')
# Out:
#                    Name       Origin     Type         Unique Feature  \
# 148     Toy Fox Terrier          USA      Toy  Miniature Fox Terrier
# 36            Chihuahua       Mexico      Toy     Smallest dog breed
# 158   Yorkshire Terrier      England      Toy        Long silky coat
# 92              Maltese        Malta      Toy        Pure white coat
# 111          Pomeranian      Germany      Toy     Fluffy double coat
# ..                  ...          ...      ...                    ...
# 98         Newfoundland       Canada  Working   Water rescue ability
# 67           Great Dane      Germany  Working             Giant size
# 124       Saint Bernard  Switzerland  Working             Large size
# 97   Neapolitan Mastiff        Italy  Working     Wrinkly loose skin
# 94              Mastiff      England  Working           Massive size
#
#      Friendly Rating (1-10)  Life Span   Size Grooming Needs  \
# 148                       8         15    Toy       Moderate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Name                             159 non-null    object
#  1   Origin                           159 non-null    object
#  2   Type                             159 non-null    object
#  3   Unique Feature                   159 non-null    object
#  4   Friendly Rating (1-10)           159 non-null    int64
#  5   Life Span                        159 non-null    int64
#  6   Size                             159 non-null    object
#  7   Grooming Needs                   159 non-null    object
#  8   Exercise Requirements (hrs/day)  159 non-null    float64
#  9   Good with Children               159 non-null    object
#  10  Intelligence Rating (1-10)       159 non-null    int64
#  11  Shedding Level                   159 non-null    object
# ...

# %%
df.describe()
# Out:
#        Friendly Rating (1-10)   Life Span  Exercise Requirements (hrs/day)  \
# count              159.000000  159.000000                       159.000000
# mean                 7.484277   12.050314                         1.842767
# std                  0.973415    1.574314                         0.450521
# min                  5.000000    7.000000                         1.000000
# 25%                  7.000000   11.000000                         1.500000
# 50%                  7.000000   12.000000                         2.000000
# 75%                  8.000000   13.000000                         2.000000
# max                 10.000000   16.000000                         3.000000
#
#        Intelligence Rating (1-10)      Weight  Training Difficulty (1-10)
# count                  159.000000  159.000000                  159.000000
# mean                     7.113208   21.600629                    6.572327
# ...

# %%
#if there is any null value by the help of describe we are able to eplace that values.
#df['Weight'].replace('2.0', 'n', inplace = True)

# %%
df.head()
# Out:
#                Name       Origin     Type          Unique Feature  \
# 0     Affenpinscher      Germany      Toy        Monkey-like face
# 1      Afghan Hound  Afghanistan    Hound         Long silky coat
# 2  Airedale Terrier      England  Terrier     Largest of terriers
# 3             Akita        Japan  Working          Strong loyalty
# 4  Alaskan Malamute   Alaska USA  Working  Strong pulling ability
#
#    Friendly Rating (1-10)  Life Span    Size Grooming Needs  \
# 0                       7         14   Small           High
# 1                       5         13   Large      Very High
# 2                       8         12  Medium           High
# 3                       6         11   Large       Moderate
# 4                       7         11   Large           High
#
#    Exercise Requirements (hrs/day) Good with Children  \
# 0                              1.5                Yes
# 1                              2.0                 No
# ...

# %%
df['wi'] = df['Weight'] + df['Life Span']
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plt.xlim(35)

# Set y-axis limits (e.g., exercise requirement range from 0 to 3)
#plt.ylim(1.5, 3)
#plt.scatter(df['Weight'], df['Exercise Requirements (hrs/day)'])  # Assuming 'Exercise_Requirements' column exists
plt.scatter(df['Life Span'], df['Weight'])
plt.xlabel('Life Span')
plt.ylabel('Weight')
plt.title('Weight vs. Exercise Requirements')
plt.grid(True)
plt.show()

# %%
sns.histplot(df['Weight'], kde=True)  # Added kde for kernel density estimation
plt.xlabel('Life Span')
plt.ylabel('Frequency')
plt.title('Distribution of Dog Weights')
plt.show()

# %%
df.groupby('Origin')['Weight'].mean().plot(kind='bar')
plt.xlabel('Origin')
df.sort_values('Origin')
plt.ylabel('Average Weight (kg)')
plt.title('Average Weight by Origin')
plt.xticks(rotation=135) # Rotate x-axis labels for better readability
plt.xlim(0,15)
plt.show()

# %%
sns.boxplot(x='Origin', y='Weight', data=df)
plt.xlabel('Origin')
plt.ylabel('Weight (kg)')
plt.title('Weight Distribution by Origin')
plt.xticks(rotation=45)
plt.xlim(0,15)
plt.show()

# %%
plt.plot(df['Life Span'], df['Weight'])  # Assuming 'Life Span' column exists
plt.xlabel('Life Span')
plt.ylabel('Weight (kg)')
plt.title('Weight vs. Life Span')
plt.grid(True)
plt.show()

# %%
sns.scatterplot(x='Weight', y='Exercise Requirements (hrs/day)', data=df)
plt.xlabel('Weight (kg)')
plt.ylabel('Exercise Requirements')
plt.title('Weight vs. Exercise Requirements')
plt.xlim(25)
plt.ylim(3)
plt.show()

# %%
df['Origin'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Dog Origins')

plt.show()

# %%
sns.histplot(df['Weight'], kde=True)
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.title('Distribution of Dog Weights')
plt.show()

# %%
sns.barplot(x='Origin', y='Weight', data=df, ci=None)  # ci=None removes confidence intervals
plt.xlabel('Origin')
plt.ylabel('Average Weight (kg)')
plt.title('Average Weight by Origin')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8480\3707596059.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Origin', y='Weight', data=df, ci=None)  # ci=None removes confidence intervals

# %%
sns.boxplot(x='Origin', y='Weight', data=df)
plt.xlabel('Origin')
plt.ylabel('Weight (kg)')
plt.title('Weight Distribution by Origin')
plt.xticks(rotation=45)
plt.show()

# %%
sns.jointplot(x='Weight',y='Life Span',data=df,kind='kde')
plt.show()
